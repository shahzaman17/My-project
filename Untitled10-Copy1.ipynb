# %% [markdown]
# First Assigement

# %%
a="shahzaman"
print(a.capitalize())
# Out:
# Shahzaman

# %%
b="PAKISTAN"
print(b.casefold())
# Out:
# pakistan

# %%
c="i like cricket"
print(c.center(60))
# Out:
#                        i like cricket

# %%
d="jjk"
print(d.count('j'))
# Out:
# 2

# %%
e="manga"
print(e.encode())
# Out:
# b'manga'

# %%
f="note"
print(f.endswith('note'))
# Out:
# True

# %%
g="RAMA\tDAN"
print(g.expandtabs(2))
# Out:
# RAMA  DAN

# %%
h="Taraveeh"
print(h.find('h'))
# Out:
# 7

# %%
i="mango is {0} rupees kg"
print(i.format(500))
# Out:
# mango is 500 rupees kg

# %%
j="Alone life is best"
print(j.index('life'))
# Out:
# 6

# %%
k="sadness is pamanent"
print(k.isalnum())
k="sadnessispamanent"
print(k.isalnum())
# Out:
# False
# True

# %%
l="I am Done"
print(i.isalpha())
# Out:
# False

# %%
m="no caption"
print(m.isascii())
# Out:
# True

# %%
n="13"
print(n.isdecimal())
n="swam"
print(n.isdecimal())
# Out:
# True
# False

# %%
o="12"
print(o.isdigit())
o="loyality"
print(o.isdigit())
# Out:
# True
# False

# %%
p="pakistan"
print(p.isidentifier())
# Out:
# True

# %%
q="believe"
print(q.islower())
# Out:
# True

# %%
r="4"
print(r.isnumeric())
r="Time"
print(r.isnumeric())
# Out:
# True
# False

# %%
S="unlucky"
print(S.isprintable())
# Out:
# True

# %%
t="   "
print(t.isspace())
# Out:
# True

# %%
u="nothing"
print(u.isupper())
u="NOTHNG"
print(u.isupper())
# Out:
# False
# True

# %%
v="villain"
print(v.join('vn'))
# Out:
# vvillainn

# %%
w="Broken Hero"
print(w.ljust(20,"s"))
# Out:
# Broken Herosssssssss

# %%
x="OBITO UCHIHA"
print(x.lower())
# Out:
# obito uchiha

# %%
Y="Itachi Uchiha"
print(Y.lstrip("Itachi"))
# Out:
#  Uchiha

# %%
Z="everything"
table=str.maketrans(".",".",'ever')
print(Z.translate(table))
# Out:
# ything

# %%
a="Darkness"
print(a.partition('k'))
# Out:
# ('Dar', 'k', 'ness')

# %%
b="anger issues"
print(b.rfind('s'))
# Out:
# 11

# %%
c="rindex"
print(c.rindex('e'))
# Out:
# 4

# %%
d="just silent"
print(d.rjust(50))
# Out:
#                                        just silent

# %%
Z="Everything"
print(Z.zfill(55))
# Out:
# 000000000000000000000000000000000000000000000Everything
